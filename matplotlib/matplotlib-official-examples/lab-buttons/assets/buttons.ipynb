# %% [markdown]
# ## Creating a Simple Button GUI to Modify a Sine Wave Using Matplotlib

# %% [markdown]
# You can practice in the code cell below. Learn how to use [Jupyter Notebooks in VS Code](https://code.visualstudio.com/docs/datascience/jupyter-notebooks). Learn how to use [Jupyter Notebooks in VS Code](https://code.visualstudio.com/docs/datascience/jupyter-notebooks).
