# %% [markdown]
# ## Cross Validation

# %% [markdown]
# Feel free to practice in the code cell below. If you are new to using Jupyter Notebook, check out the [Jupyter Notebook Documentation](https://jupyter-notebook.readthedocs.io/en/stable/).
