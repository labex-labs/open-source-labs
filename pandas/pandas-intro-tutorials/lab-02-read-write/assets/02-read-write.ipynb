# %% [markdown]
# ## Pandas Data Manipulation Lab

# %% [markdown]
# You can practice in the code cell below. If you are unfamiliar with using Jupyter Notebook, click on the Help menu above for assistance.
